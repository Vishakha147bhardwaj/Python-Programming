# %%
# !pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
url = "https://realpython.github.io/fake-jobs/"

response = requests.get(url)

print("Status Code:", response.status_code)
# Out:
# Status Code: 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

print(soup.title.text)
# Out:
# Fake Python

# %%
job_cards = soup.find_all("div", class_="card-content")

print("Total Jobs Found:", len(job_cards))
# Out:
# Total Jobs Found: 100

# %%
jobs = []

for job in job_cards:

    title = job.find("h2", class_="title").text.strip()

    company = job.find("h3", class_="company").text.strip()

    location = job.find("p", class_="location").text.strip()

    date = job.find("time").text.strip()

    jobs.append({
        "Job Title": title,
        "Company": company,
        "Location": location,
        "Date Posted": date
    })

print("Jobs Extracted:", len(jobs))
# Out:
# Jobs Extracted: 100

# %%
[
    {
        "Job Title": "Senior Python Developer",
        "Company": "Payne, Roberts and Davis",
        "Location": "Stewartbury, AA",
        "Date Posted": "2021-04-08"
    },
    {
        "Job Title": "Energy engineer",
        "Company": "Vasquez-Davidson",
        "Location": "Christopherville, AA",
        "Date Posted": "2021-04-08"
    }
]
# Out:
# [{'Job Title': 'Senior Python Developer',
#   'Company': 'Payne, Roberts and Davis',
#   'Location': 'Stewartbury, AA',
#   'Date Posted': '2021-04-08'},
#  {'Job Title': 'Energy engineer',
#   'Company': 'Vasquez-Davidson',
#   'Location': 'Christopherville, AA',
#   'Date Posted': '2021-04-08'}]

# %%
with open("fake_jobs.json", "w", encoding="utf-8") as file:
    json.dump(jobs, file, indent=4)

print(" JSON file created successfully!")
# Out:
#  JSON file created successfully!

# %%
with open("fake_jobs.json", "r", encoding="utf-8") as file:
    data = json.load(file)

print("Total Records:", len(data))
print(data[0])
# Out:
# Total Records: 100
# {'Job Title': 'Senior Python Developer', 'Company': 'Payne, Roberts and Davis', 'Location': 'Stewartbury, AA', 'Date Posted': '2021-04-08'}
