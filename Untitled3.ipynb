# %%
Import sql
Connection =sqlite3.connect()
Cursor = connection.cursor()
Cursor.execute(“”” CREATE TABLE EMPLOYEE IF NOT EXISTS ( EMPLOYEEID INT primary key, employeename text, companyname text)”””) 
Cursor.executemany("INSERT INTO EMPLOYEE VALUES (???)"
                  [(1,'Abhay','ABC')
    (2,'Riya','XYZ)
    ])

Cursor.execute(“”” CREATE TABLE DEPARTMENT IF NOT EXISTS ( DEPARTMENTNAME TEXT, EMPLOYEEID INT primary key, employeename text, companyname text)”””) 
Cursor.executemany("INSERT INTO DEPARTMENT VALUES (???)"
                  [('DD',1)
    ('IT',2)
    ])
cursor.execute("SELECT EMPLOYEEID FROM EMPLOYEE
INNER JOIN EMPLOYEE(EMPLOYEE.ID = DEPARTMENT(EMPLOYEEID))
# Out:
#   Cell In[1], line 4
#     Cursor.execute(“”” CREATE TABLE EMPLOYEE IF NOT EXISTS ( EMPLOYEEID INT primary key, employeename text, companyname text)”””)
#                    ^
# SyntaxError: invalid character '“' (U+201C)
