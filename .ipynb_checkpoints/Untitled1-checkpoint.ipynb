# %%
import pandas as pd

# Creating mock data: Monthly sales performance for a store
data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
    'Sales_USD':[2000,3000,2500,4500,3300,1000,6600,2300,4700,8769,1965,10000],
    'Customers': [400, 450, 420, 510, 580, 620, 550, 590, 680, 710, 800, 950]
}

# Turn the data into a spreadsheet (DataFrame) and save it
df_mock = pd.DataFrame(data)
df_mock.to_csv('company_sales.csv', index=False)
print("Success! 'company_sales.csv' has been created in your workspace.")
# Out:
# Success! 'company_sales.csv' has been created in your workspace.

# %%
# 2. Read the spreadsheet file
sales_data = pd.read_csv('company_sales.csv')

# 3. View the first 5 rows (The "Head" of the data)
sales_data.head(12)
# Out:
#    Month  Sales_USD  Customers
# 0    Jan       2000        400
# 1    Feb       3000        450
# 2    Mar       2500        420
# 3    Apr       4500        510
# 4    May       3300        580
# 5    Jun       1000        620
# 6    Jul       6600        550
# 7    Aug       2300        590
# 8    Sep       4700        680
# 9    Oct       8769        710
# 10   Nov       1965        800
# 11   Dec      10000        950

# %%
# 4. Inspect the structure (How many rows and columns?)
print("Dataset dimensions (Rows, Columns):")
print(sales_data.shape)
# Out:
# Dataset dimensions (Rows, Columns):
# (12, 3)

# %%
# 5. Get a quick summary of numerical values (Averages, Max, Min)
sales_data.describe()
